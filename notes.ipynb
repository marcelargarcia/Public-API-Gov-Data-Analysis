# %% [markdown]
# Project Description and KPIs
#
# Add

# %% [markdown]
# Data 📊 - Description and modeling
#
# Add

# %% [markdown]
# Step 1: Data Collection & Inspection -
# Retrieve data from APIs and examine them for issues like missing values, inconsistencies, errors, and duplicates.

# %%
import json
import requests
import pandas as pd


# # BR Corporate Cards Data
def _get_corp_cards():
    url = "https://api.portaldatransparencia.gov.br/api-de-dados/cartoes?dataTransacaoFim=30%2F07%2F2023&dataTransacaoInicio=01%2F01%2F2023&pagina=1"

    payload = {}
    headers = {
      'chave-api-dados': '7048f20892f6e59dc78cf7707e8ad843',
      'Cookie': 'JSESSIONID=358C2ECB5CB444691D06750877E67077'
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    return response

# BR COVID - SUS Data
def _get_covid_data():
  url = "https://imunizacao-es.saude.gov.br/_search"
  payload = json.dumps({
    "size": 10000
  })
  headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k='
  }    

  response = requests.request("GET", url, headers=headers, data=payload)
  return response

def _get_per_page(complete_url, page_number):
    page_number_parameter = "&page[number]=" + str(page_number)
    url = complete_url + page_number_parameter
    with urllib.request.urlopen(url) as response:
        response_json = json.loads(response.read())
        df = pd.DataFrame.from_dict(response_json['data'])
        #total_pages = int(response_json["meta"]["total-pages"])
        return df


# BR Cities - IBGE Data
def _get_cities_data():
  url = "http://servicodados.ibge.gov.br/api/v1/localidades/municipios"
  response = requests.get(url)
  return response

# %%
cities_data = _get_cities_data().json()
df_cities_data = pd.json_normalize(cities_data)
df_cities_data
# Out:
#            id                   nome  microrregiao.id    microrregiao.nome  \
# 0     1100015  Alta Floresta D'Oeste            11006               Cacoal
# 1     1100023              Ariquemes            11003            Ariquemes
# 2     1100031                 Cabixi            11008    Colorado do Oeste
# 3     1100049                 Cacoal            11006               Cacoal
# 4     1100056             Cerejeiras            11008    Colorado do Oeste
# ...       ...                    ...              ...                  ...
# 5565  5222005             Vianópolis            52016         Pires do Rio
# 5566  5222054         Vicentinópolis            52015           Meia Ponte
# 5567  5222203               Vila Boa            52012  Entorno de Brasília
# 5568  5222302          Vila Propício            52012  Entorno de Brasília
# 5569  5300108               Brasília            53001             Brasília
#
#       microrregiao.mesorregiao.id microrregiao.mesorregiao.nome  \
# ...

# %%
#Listing AM cities 
cities_data = _get_cities_data().json()
df_cities_data = pd.json_normalize(cities_data)
am_cities = df_cities_data.query('`microrregiao.mesorregiao.UF.sigla` == "AM"')
am_cities = list(am_cities['nome'])
am_cities = [x.upper() for x in am_cities]
am_cities
# Out:
# ['ALVARÃES',
#  'AMATURÁ',
#  'ANAMÃ',
#  'ANORI',
#  'APUÍ',
#  'ATALAIA DO NORTE',
#  'AUTAZES',
#  'BARCELOS',
#  'BARREIRINHA',
#  'BENJAMIN CONSTANT',
#  'BERURI',
#  'BOA VISTA DO RAMOS',
#  'BOCA DO ACRE',
#  'BORBA',
#  'CAAPIRANGA',
#  'CANUTAMA',
#  'CARAUARI',
#  'CAREIRO',
#  'CAREIRO DA VÁRZEA',
#  'COARI',
#  'CODAJÁS',
#  'EIRUNEPÉ',
#  'ENVIRA',
#  'FONTE BOA',
#  'GUAJARÁ',
#  'HUMAITÁ',
#  'IPIXUNA',
#  'IRANDUBA',
#  'ITACOATIARA',
#  'ITAMARATI',
#  'ITAPIRANGA',
#  'JAPURÁ',
#  'JURUÁ',
#  'JUTAÍ',
#  'LÁBREA',
#  'MANACAPURU',
#  'MANAQUIRI',
#  'MANAUS',
#  'MANICORÉ',
#  'MARAÃ',
#  'MAUÉS',
#  'NHAMUNDÁ',
#  'NOVA OLINDA DO NORTE',
#  'NOVO AIRÃO',
#  'NOVO ARIPUANÃ',
#  'PARINTINS',
#  'PAUINI',
#  'PRESIDENTE FIGUEIREDO',
#  'RIO PRETO DA EVA',
#  'SANTA ISABEL DO RIO NEGRO',
#  'SANTO ANTÔNIO DO IÇÁ',
#  'SÃO GABRIEL DA CACHOEIRA',
#  'SÃO PAULO DE OLIVENÇA',
#  'SÃO SEBASTIÃO DO UATUMÃ',
#  'SILVES',
#  'TABATINGA',
#  'TAPAUÁ',
#  'TEFÉ',
# ...

# %%
#Filtering AM cities only
vaccine = _get_covid_data().json()
df_vaccine = pd.json_normalize(vaccine['hits']['hits'])
#df_vaccine['_source.estabelecimento_municipio_nome']
df_vaccine = df_vaccine[df_vaccine['_source.estabelecimento_municipio_nome'].isin(am_cities)]
df_vaccine.info()
df_vaccine
# df_vaccine.rename(columns={})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413 entries, 6 to 9983
# Data columns (total 46 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   _index                                            413 non-null    object
#  1   _type                                             413 non-null    object
#  2   _id                                               413 non-null    object
#  3   _score                                            413 non-null    float64
#  4   _source.paciente_nacionalidade_enumNacionalidade  413 non-null    object
#  5   _source.vacina_categoria_codigo                   413 non-null    object
#  6   _source.paciente_endereco_nmMunicipio             413 non-null    object
#  7   _source.paciente_id                               413 non-null    object
#  8   _source.paciente_dataNascimento                   413 non-null    object
# ...

# %%
cards = pd.json_normalize(_get_corp_cards().json())
cards
# Out:
#            id mesExtrato dataTransacao valorTransacao  tipoCartao.id  \
# 0   346550462    03/2023    06/02/2023         366,00              1
# 1   346550464    03/2023    13/02/2023          60,00              1
# 2   346550465    03/2023    10/02/2023         425,00              1
# 3   346550469    03/2023    03/02/2023         340,00              1
# 4   346550470    03/2023    09/02/2023       1.000,00              1
# 5   346550471    03/2023    09/02/2023       1.000,00              1
# 6   346550472    03/2023    09/02/2023         500,00              1
# 7   346550473    03/2023    09/02/2023         510,00              1
# 8   346550474    03/2023    09/02/2023         700,00              1
# 9   346550477    03/2023    15/02/2023         205,00              1
# 10  346550478    03/2023    03/02/2023          62,00              1
# 11  346550484    03/2023    10/02/2023         150,00              1
# 12  346550492    03/2023    09/02/2023         750,00              1
# ...

# %%
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

number = '1.112,75'

number = list(number)
i  = 0
while i < len(number):
  if number[i] == '.':
    number[i] = ','
  elif number[i] == ',':
    number[i] = '.'
  i +=1

number = locale.atof(''.join(number))
print(number)



# parsed_number = locale.atof(number)
# print(parsed_number)

# parsed_number = str(parsed_number).replace('.',',')
# print(parsed_number)


# number2 = '11,26'
# parsed_number2 = locale.currency(number2)
# parsed_number2
# Out:
# 1112.75
